# %%
import numpy as np

x = np.array([0,0,1,1,1])
def last1_occur(x):
    store = 0
    count = 0
    n = len(x)
    i = 1 - n


    for i in x:
      if i == 1:
        store += i
      else:
        count += 1


    return [0]*count + [1]*store
print(last1_occur(x))
# Out:
# [0, 0, 1, 1, 1]
