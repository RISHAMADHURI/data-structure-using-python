# %%
#positive indexing
import numpy as np
x = np.array([11,15,26,38,9,10])
target = int(input())
def positive_index(x,target):
  n = len(x)
  for i in range(n):
    if x[i] == target:
      print(i)

positive_index(x,target)
# Out:
# 10
# 5
